# %%
# Import Everything
from keras.models import Sequential, Model
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.normalization import BatchNormalization
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, Deconvolution2D, Input, merge
from keras.layers.core import Flatten
from keras.optimizers import Adam
from keras import backend as K
from keras.models import load_model
import numpy as np
import sys, glob
import cv2
import os
import argparse
from sklearn.feature_extraction.image import extract_patches_2d

# Utility Scripts for Image Loading

def load_image(path):
    img = cv2.imread(path, 1)
    img = np.rollaxis(np.float32(img), 2, 0)
    return img
  
def get_batches(paths_a, batch_size):
    for i in range(len(paths_a)/batch_size):
        yield i, [load_image(path) for path in paths_a[i*batch_size : (i + 1) * batch_size]]

def get_new_batch(path_input, resize_size = 1.):   
    paths = glob.glob(os.path.join(path_input, "*.png"))
    all_patches = []
    print paths
    from scipy.misc import imresize
    for index, image_batch_a in get_batches(paths, batch_size=1):
        current_im = image_batch_a[0]
        current_im  = np.expand_dims(current_im, axis = 0)
        all_patches.append(current_im)
    X_H = np.concatenate(all_patches)

    return X_H
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5105)

# %%
# Load Input/Output
X_A = get_new_batch('D:\street_data\segmentation', 0.25)
X_B = get_new_batch('D:\street_data\\flowx', 0.25)
X_C = get_new_batch('D:\street_data\\flowy', 0.25)
X_D = get_new_batch('D:\street_data\\raw', 0.25)
X = np.concatenate((X_A,X_B,X_C,X_D), axis = 1)

Y_train = X_A[0::2,:,::2,::2]
X_train = X[1::2,:,::2,::2]
# Out:
# ['D:\\street_data\\segmentation\\10_test_.png', 'D:\\street_data\\segmentation\\10_train_.png', 'D:\\street_data\\segmentation\\11_test_.png', 'D:\\street_data\\segmentation\\11_train_.png', 'D:\\street_data\\segmentation\\12_test_.png', 'D:\\street_data\\segmentation\\12_train_.png', 'D:\\street_data\\segmentation\\13_test_.png', 'D:\\street_data\\segmentation\\13_train_.png', 'D:\\street_data\\segmentation\\14_test_.png', 'D:\\street_data\\segmentation\\14_train_.png', 'D:\\street_data\\segmentation\\15_test_.png', 'D:\\street_data\\segmentation\\15_train_.png', 'D:\\street_data\\segmentation\\16_test_.png', 'D:\\street_data\\segmentation\\16_train_.png', 'D:\\street_data\\segmentation\\17_test_.png', 'D:\\street_data\\segmentation\\17_train_.png', 'D:\\street_data\\segmentation\\18_test_.png', 'D:\\street_data\\segmentation\\18_train_.png', 'D:\\street_data\\segmentation\\19_test_.png', 'D:\\street_data\\segmentation\\19_train_.png', 'D:\\street_data\\segmentation\\1_test_.png', 'D:\\street_data\\segmentation\\1_train_.png', 'D:\\street_data\\segmentation\\20_test_.png', 'D:\\street_data\\segmentation\\20_train_.png', 'D:\\street_data\\segmentation\\21_test_.png', 'D:\\street_data\\segmentation\\21_train_.png', 'D:\\street_data\\segmentation\\22_test_.png', 'D:\\street_data\\segmentation\\22_train_.png', 'D:\\street_data\\segmentation\\23_test_.png', 'D:\\street_data\\segmentation\\23_train_.png', 'D:\\street_data\
'D:\\street_data\\raw\\42_test_.png', 'D:\\street_data\\raw\\42_train_.png', 'D:\\street_data\\raw\\43_test_.png', 'D:\\street_data\\raw\\43_train_.png', 'D:\\street_data\\raw\\44_test_.png', 'D:\\street_data\\raw\\44_train_.png', 'D:\\street_data\\raw\\45_test_.png', 'D:\\street_data\\raw\\45_train_.png', 'D:\\street_data\\raw\\46_test_.png', 'D:\\street_data\\raw\\46_train_.png', 'D:\\street_data\\raw\\47_test_.png', 'D:\\street_data\\raw\\47_train_.png', 'D:\\street_data\\raw\\48_test_.png', 'D:\\street_data\\raw\\48_train_.png', 'D:\\street_data\\raw\\49_test_.png', 'D:\\street_data\\raw\\49_train_.png', 'D:\\street_data\\raw\\4_test_.png', 'D:\\street_data\\raw\\4_train_.png', 'D:\\street_data\\raw\\50_test_.png', 'D:\\street_data\\raw\\50_train_.png', 'D:\\street_data\\raw\\51_test_.png', 'D:\\street_data\\raw\\51_train_.png', 'D:\\street_data\\raw\\52_test_.png', 'D:\\street_data\\raw\\52_train_.png', 'D:\\street_data\\raw\\53_test_.png', 'D:\\street_data\\raw\\53_train_.png', 'D:\\street_data\\raw\\54_test_.png', 'D:\\street_data\\raw\\54_train_.png', 'D:\\street_data\\raw\\55_test_.png', 'D:\\street_data\\raw\\55_train_.png', 'D:\\street_data\\raw\\56_test_.png', 'D:\\street_data\\raw\\56_train_.png', 'D:\\street_data\\raw\\57_test_.png', 'D:\\street_data\\raw\\57_train_.png', 'D: ...

# %%
# Custom Keras Layer for Softmax (Segmentation)
import theano.tensor as T
from keras import backend as K
from keras.engine.topology import Layer
class PixelLayer(Layer):
    def __init__(self, **kwargs):
        super(PixelLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.trainable_weights = []

    def call(self, input, mask=None):
        (bs, cc, h, w) = input.shape
        tmp = input.transpose((0,2,3,1))
        tmp = tmp.reshape((bs*h*w, cc))
        tmp = T.nnet.nnet.softmax(tmp)
        output = tmp.reshape((bs, h, w, cc))
        output = output.transpose((0,3,1,2))
        return output

    def get_output_shape_for(self, shape):
        return (shape[0], shape[1], shape[2], shape[3])
    
# Deep Learning Model Parameters
filter_set = [32,32,32,32]
# Define Model
inita = Input(shape=(12,512,512))
init = inita
n_layers = len(filter_set)
cs = []
for i in range(n_layers-1):
    in_layer = Convolution2D(filter_set[i], 3, 3, activation='relu', border_mode='same')(init)
    x = BatchNormalization(mode=2, axis=1)(in_layer)
    cs.append(Convolution2D(filter_set[i], 3, 3, activation='relu', border_mode='same')(x))
    cs[i] = BatchNormalization(mode=2, axis=1)(cs[i])
    init = MaxPooling2D((2, 2))(cs[i])
init = Convolution2D(filter_set[i+1], 3, 3, activation='relu', border_mode='same')(init)
for i in range(n_layers-1):
    init = UpSampling2D()(init)
    ck = Convolution2D(filter_set[n_layers-i-2], 3, 3, activation='relu', border_mode='same')(init)
    ck = BatchNormalization(mode=2, axis=1)(ck)
    ck = Convolution2D(filter_set[n_layers-i-2], 3, 3, activation='relu', border_mode='same')(ck)
    ck = BatchNormalization(mode=2, axis=1)(ck)
    init = merge([cs[n_layers-i-2], ck], mode='sum')

decoded = Convolution2D(3, 5, 5, activation='linear', border_mode='same')(init)
decoded = BatchNormalization(mode=2, axis=1)(decoded)
decoded = PixelLayer()(decoded)

# Prepare Training
import keras
es = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
er = keras.callbacks.ModelCheckpoint('segcheck', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only = True)
full_model = Model(input=inita, output=decoded)
full_model.compile(loss='mse',
        optimizer='Nadam')
full_model.summary()

errors = []

from keras.models import load_model
full_model.load_weights('segcheck')
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 12, 512, 512)  0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 32, 512, 512)  3488        input_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNormal(None, 32, 512, 512)  64          convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 32, 512, 512)  9248        batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNormal(None, 32, 512, 512)  64          convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 32, 256, 256)  0           batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 32, 256, 256)  9248        maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNormal(None, 32, 256, 256)  64          convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 32, 256, 256)  9248        batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNormal(None, 32, 256, 256)  64          convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 32, 128, 128)  0           batchnormalization_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 32, 128, 128)  9248        maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_5 (BatchNormal(None, 32, 128, 128)  64          convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)  (None, 32, 128, 128)  9248        batchnormalization_5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_6 (BatchNormal(None, 32, 128, 128)  64          convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)    (None, 32, 64, 64)    0           batchnormalization_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)  (None, 32, 64, 64)    9248        maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)    (None, 32, 128, 128)  0           convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)  (None, 32, 128, 128)  9248        upsampling2d_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_7 (BatchNormal(None, 32, 128, 128)  64          convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)  (None, 32, 128, 128)  9248        batchnormalization_7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_8 (BatchNormal(None, 32, 128, 128)  64          convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                  (None, 32, 128, 128)  0           batchnormalization_6[0][0]
#                                                                    batchnormalization_8[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)    (None, 32, 256, 256)  0           merge_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D) (None, 32, 256, 256)  9248        upsampling2d_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_9 (BatchNormal(None, 32, 256, 256)  64          convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D) (None, 32, 256, 256)  9248        batchnormalization_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_10 (BatchNorma(None, 32, 256, 256)  64          convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 32, 256, 256)  0           batchnormalization_4[0][0]
#                                                                    batchnormalization_10[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)    (None, 32, 512, 512)  0           merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D) (None, 32, 512, 512)  9248        upsampling2d_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_11 (BatchNorma(None, 32, 512, 512)  64          convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D) (None, 32, 512, 512)  9248        batchnormalization_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_12 (BatchNorma(None, 32, 512, 512)  64          convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                  (None, 32, 512, 512)  0           batchnormalization_2[0][0]
#                                                                    batchnormalization_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D) (None, 3, 512, 512)   2403        merge_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_13 (BatchNorma(None, 3, 512, 512)   6           convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# pixellayer_1 (PixelLayer)        (None, 3, 512, 512)   0           batchnormalization_13[0][0]
# ====================================================================================================
# Total params: 117641
# ____________________________________________________________________________________________________

# %%
# Get Results
results = full_model.predict(X_train[-5:] / 255. , batch_size = 1)

# %%
### Elementary Testing Code
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  


img_idx = 0
#import PyQt4
class_results = np.argmax(results, axis = 1)
#%matplotlib notebook
resultsa = 1. * (results > 0.5)
fig = plt.figure(figsize=(12, 12))
for j in range(1):
    a=fig.add_subplot(3,4,1+j*4)
    plt.imshow(np.transpose(X_train[-1,0:3,:,:],(1,2,0))[:,:,(2,1,0)] / 255.)
    a.set_title('Input')
    plt.axis('off')
    a=fig.add_subplot(3,4,2+j*4)
    plt.imshow(np.transpose(Y_train[-1,0:3,:,:],(1,2,0))[:,:,(2,1,0)] / 255.)
    a.set_title('Ground Truth')
    plt.axis('off')
    a=fig.add_subplot(3,4,3+j*4)
    plt.imshow(np.transpose(results[-1],(1,2,0))[:,:,(2,1,0)])
    a.set_title('Our Prediction')
    plt.axis('off')
    a=fig.add_subplot(3,4,4+j*4)
    plt.imshow(np.transpose(class_results[-2],(0,1)), cmap= plt.get_cmap('gray'))
    a.set_title('Hard Prediction')
    plt.axis('off')
    cv2.imwrite('input_' + str(j) + '.png',   (np.transpose(X_A[-5],(1,2,0))[:,:,(2,1,0)]))
    cv2.imwrite('pr_ground_truth_' + str(j) + '.png', (np.transpose(X_A[-4],(1,2,0))[:,:,(2,1,0)] ))
    cv2.imwrite('pr_soft_predictions_' + str(j) + '.png', 255. * (np.transpose(results[0],(1,2,0))[:,:,(2,1,0)]))
    cv2.imwrite('pr_hard_predictions_' + str(j) + '.png', 127.5 * (np.transpose(class_results[0],(0,1))))
